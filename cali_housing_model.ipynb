# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
X = data.drop(['median_house_value'], axis =1)
Y = data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
Y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)

# %%
train_data = X_train.join(Y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2565     -124.15     40.78                41.0       2127.0           358.0
# 8938     -118.47     34.01                41.0       2704.0           557.0
# 10286    -117.83     33.89                25.0       1737.0           270.0
# 6721     -118.14     34.13                16.0       3569.0           821.0
# 2760     -115.52     32.67                 6.0       2804.0           581.0
# ...          ...       ...                 ...          ...             ...
# 6787     -118.15     34.09                27.0       1935.0           460.0
# 3911     -118.55     34.20                21.0       2549.0           651.0
# 15235    -117.26     32.96                36.0       1721.0           264.0
# 1258     -121.63     38.03                17.0       2549.0           596.0
# 5483     -118.46     33.99                37.0       1828.0           460.0
#
# ...

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only=True), annot = True, cmap ="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households']+1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2565     -124.15     40.78                41.0     7.662938        5.883322
# 8938     -118.47     34.01                41.0     7.902857        6.324359
# 10286    -117.83     33.89                25.0     7.460490        5.602119
# 6721     -118.14     34.13                16.0     8.180321        6.711740
# 2760     -115.52     32.67                 6.0     7.939159        6.366470
# ...          ...       ...                 ...          ...             ...
# 6787     -118.15     34.09                27.0     7.568379        6.133398
# 3911     -118.55     34.20                21.0     7.843849        6.480045
# 15235    -117.26     32.96                36.0     7.451242        5.579730
# 1258     -121.63     38.03                17.0     7.843849        6.391917
# 5483     -118.46     33.99                37.0     7.511525        6.133398
#
# ...

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
op=pd.get_dummies(train_data.ocean_proximity)

# %%
op = op.astype('int')
print(op)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 2565           0       0       0         0           1
# 8938           1       0       0         0           0
# 10286          1       0       0         0           0
# 6721           1       0       0         0           0
# 2760           0       1       0         0           0
# ...          ...     ...     ...       ...         ...
# 6787           1       0       0         0           0
# 3911           1       0       0         0           0
# 15235          0       0       0         0           1
# 1258           0       1       0         0           0
# 5483           1       0       0         0           0
#
# [16346 rows x 5 columns]

# %%
train_data1=train_data.join(op).drop(['ocean_proximity'], axis =1)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data1.corr(numeric_only=True), annot = True, cmap ="YlGnBu")
# Out:
# <Axes: >

# %%
train_data1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2565     -124.15     40.78                41.0     7.662938        5.883322
# 8938     -118.47     34.01                41.0     7.902857        6.324359
# 10286    -117.83     33.89                25.0     7.460490        5.602119
# 6721     -118.14     34.13                16.0     8.180321        6.711740
# 2760     -115.52     32.67                 6.0     7.939159        6.366470
# ...          ...       ...                 ...          ...             ...
# 6787     -118.15     34.09                27.0     7.568379        6.133398
# 3911     -118.55     34.20                21.0     7.843849        6.480045
# 15235    -117.26     32.96                36.0     7.451242        5.579730
# 1258     -121.63     38.03                17.0     7.843849        6.391917
# 5483     -118.46     33.99                37.0     7.511525        6.133398
#
# ...

# %%
plt.figure(figsize=(15, 8))
sns.scatterplot(
    x="latitude",
    y="longitude",
    data=train_data1,
    hue="median_house_value",
    palette="coolwarm"
)
plt.title("Scatterplot of Latitude and Longitude with Median House Value")
plt.show()

# %%
train_data1['bedroom_ratio']= train_data1['total_bedrooms']/train_data1['total_rooms']
train_data1['household_rooms']= train_data1['total_rooms']/train_data1['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data1.corr(numeric_only=True), annot = True, cmap ="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
x_train, y_train =train_data1.drop(['median_house_value'], axis=1), train_data1['median_house_value']
X_train_s =scaler.fit_transform(X_train)
reg =LinearRegression()
reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
import pandas as pd

# Split the data into features and target
X_train = train_data1.drop(['median_house_value'], axis=1)
y_train = train_data1['median_house_value']

# Handle categorical data (e.g., "ocean_proximity")
if 'ocean_proximity' in X_train.columns:
    label_encoder = LabelEncoder()
    X_train['ocean_proximity'] = label_encoder.fit_transform(X_train['ocean_proximity'])

# Ensure all columns are numeric
print(X_train.dtypes)

# Scale the features
scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)

# Fit a linear regression model
reg = LinearRegression()
reg.fit(X_train_s, y_train)

# Model coefficients
print("Coefficients:", reg.coef_)
print("Intercept:", reg.intercept_)
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# <1H OCEAN               int32
# INLAND                  int32
# ISLAND                  int32
# NEAR BAY                int32
# NEAR OCEAN              int32
# bedroom_ratio         float64
# household_rooms       float64
# dtype: object
# Coefficients: [-59505.5589859  -61364.14403602  13482.84312597 -71388.93762643
#  114113.1453677  -65974.95589224  34619.28918986  81423.2831446
#    5634.55793565  -9659.01010228   2630.17264397   1460.52134986
#    3533.34615195 -14902.08877974    729.54388862]
# Intercept: 207635.79915575695

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# Separate features and target for training
X_train, y_train = train_data1.drop(['median_house_value'], axis=1), train_data1['median_house_value']

# Standardize the features
scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)

# Train the model with the transformed data
reg = LinearRegression()
reg.fit(X_train_s, y_train)

# For testing, ensure consistency in format
X_test_s = scaler.transform(X_test)  # Apply the same transformation to test data
score = reg.score(X_test_s, y_test)  # Model evaluation
print(f"Model Score: {score}")
# Out:
# Model Score: 0.6719478348327874
